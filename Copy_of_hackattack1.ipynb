# %%
pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.2/608.2 KB 44.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 14.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.7.0.72
#     Uninstalling opencv-python-headless-4.7.0.72:
#       Successfully uninstalled opencv-python-headless-4.7.0.72
# ...

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("/content/00000009.jpg")

# %%
plt.imshow(img)

# %%
ocr=easyocr.Reader(['en'])
# Out:
# WARNING:easyocr.easyocr:CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
result1=ocr.readtext(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3da8e49ad076> in <module>
# ----> 1 result1=ocr.readtext(img)
#
# NameError: name 'img' is not defined

# %%
img2=cv2.imread("/content/eefbdf3c-ed34-4e4a-85cd-ed227a4044dd.jpeg")

# %%
plt.imshow(img2)

# %%
result2=ocr.readtext(img2)
result2
# Out:
# [([[269, 515], [417, 515], [417, 547], [269, 547]],
#   'Ka05hz4024',
#   0.5984443062811676)]

# %%
img3=cv2.imread("/content/00000044.jpg")

# %%
plt.imshow(img3)

# %%
result=ocr.readtext(img3)
result
# Out:
# [([[211, 711], [253, 711], [253, 731], [211, 731]], 'IND', 0.9962901267633334),
#  ([[278, 636], [894, 636], [894, 740], [278, 740]],
#   'KA OZP 7283',
#   0.21923734916522453),
#  ([[754.2269358608581, 209.03743936683853],
#    [885.9680403416935, 261.2856239693654],
#    [857.7730641391419, 327.96256063316144],
#    [725.0319596583065, 275.7143760306346]],
#   'aprl',
#   0.8444764018058777)]

# %%
for i in result2:
  for j in i:
    if j=="IND":
      print('valid')
      break
print('not valid')
# Out:
# not valid

# %%
img4=cv2.imread("/content/00000035.jpg")

# %%
plt.imshow(img4)

# %%
result4=ocr.readtext(img4)
result4
# Out:
# [([[383, 93], [415, 93], [415, 113], [383, 113]], '00', 0.5639768422362794),
#  ([[174, 146], [292, 146], [292, 196], [174, 196]],
#   'TZ3',
#   0.40812003847320555),
#  ([[157, 178], [302, 178], [302, 233], [157, 233]],
#   'Jo158',
#   0.730034345557378)]

# %%
for i in result4:
  for j in i:
    if j=="IND":
      print('valid')
      break
print('not valid')
# Out:
# not valid
